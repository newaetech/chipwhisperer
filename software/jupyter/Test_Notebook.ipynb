# %%
import os
import subprocess
import tempfile
from pathlib import Path
import io

import nbformat

def _notebook_run(path):
    """Execute a notebook via nbconvert and collect output.
       :returns (parsed nb object, execution errors)
    """
    html_path = Path("html/" + path + ".html")
    real_path = Path(path)
    with tempfile.NamedTemporaryFile(dir=".", suffix=".ipynb", delete=False) as fout:
        name = fout.name
        fout.close()
        
        args = ["jupyter","nbconvert", "--to", "notebook", "--execute",
                "--ExecutePreprocessor.timeout=None", "--ExecutePreprocessor.allow_errors=True",
                "--output", fout.name, str(real_path)]
        
        try:
            subprocess.check_output(args, stderr=subprocess.STDOUT)
            
            ## convert to HTML as well
            args = ["jupyter","nbconvert", "--to", "html",
                "--ExecutePreprocessor.timeout=None",
                "--output", str(html_path), fout.name]
            subprocess.check_output(args, stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as e:
            print(e)
            print(e.output)
            return
        fout = open(name, "r", encoding='utf-8')
        fout.seek(0)
        nb = nbformat.read(fout, nbformat.current_nbformat)
        fout.close()
        os.remove(name)

    errors = [[i+1,output] for i,cell in enumerate(nb.cells) if "outputs" in cell
                    for output in cell["outputs"]\
                            if output.output_type == "error"]

    return nb, errors

def _print_tracebacks(errors):
    if errors == []:
        print("Passed all tests!")
    for error in errors:
        print("Test failed in cell {}: {}: {}".format(error[0], error[1]['ename'], error[1]['evalue']))
        for line in error[1]['traceback']:
            print(line)
            
def _get_outputs(nb):
    return [[i,cell] for i,cell in enumerate(nb.cells) if "outputs" in cell]
    
def _print_stderr(nb):
    outputs = _get_outputs(nb)
    printed_output = [[cell[0], output] for cell in outputs for output in cell[1]['outputs'] if ('name' in output and output['name'] == 'stderr')]
    for out in printed_output:
        print("[{}]:\n{}".format(out[0], out[1]['text']))
        
def _print_stdout(nb):
    outputs = _get_outputs(nb)
    printed_output = [[cell[0], output] for cell in outputs for output in cell[1]['outputs'] if ('name' in output and output['name'] == 'stdout')]
    for out in printed_output:
        print("[{}]:\n{}".format(out[0], out[1]['text']))
        
def test_notebook(path, print_stdout=False, print_stderr=False):
    print("Testing: {}:...".format(path), end="")
    nb, errors = _notebook_run(path)
    if errors == []:
        print("PASSED")
    else:
        print("FAILED:")
        _print_tracebacks(errors)
    if print_stdout:
        _print_stdout(nb)
    if print_stderr:
        _print_stderr(nb)

# %%
# %%bash
# mkdir -p html
# cd ../../hardware/victims/firmware
# rm -rf simpleserial-base-lab*
# rm -rf glitch-simple-lab*
# rm -rf simpleserial-aes-lab*

# %%
test_notebook('PA_Intro_1-Firmware_Build_Setup.ipynb')
test_notebook('PA_Intro_2-Instruction_Differences.ipynb')

# %%
test_notebook('PA_SPA_1-Timing_Analysis_with_Power_for_Password_Bypass.ipynb')

# %%
#test_notebook('PA_DPA_1-Hamming_Weight_Measurement.ipynb') #FAILS, COMPILER MOVED SPOT
test_notebook('PA_DPA_2-Large_HW_Swings.ipynb')

# %%
test_notebook('PA_CPA_1-Using_CW-Analyzer_for_CPA_Attack.ipynb')
test_notebook('PA_CPA_2-Manual_CPA_Attack.ipynb')
test_notebook('PA_CPA_3-Resynchronizing_Data_Traces.ipynb')
#test_notebook('PA_CPA_4-Hardware_Crypto_Attack.ipynb') #FAILS
test_notebook('PA_CPA_5-32bit_AES.ipynb') #MAY FAIL
# Out:
# Testing: PA_CPA_1-Using_CW-Analyzer_for_CPA_Attack.ipynb:...PASSED
# Testing: PA_CPA_2-Manual_CPA_Attack.ipynb:...PASSED
# Testing: PA_CPA_3-Resynchronizing_Data_Traces.ipynb:...PASSED
# Testing: PA_CPA_5-32bit_AES.ipynb:...FAILED:
# Test failed in cell 20: AttributeError: 'int' object has no attribute 'sigTracesChanged'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a7d61d44a422> in <module>
#       5 leak_model = cw.AES128(cw.AES128Leakage.SBox_output)
#       6 attack.setAnalysisAlgorithm(cw.CPAProgressive, leak_model)
# ----> 7 attack.setTraceSource(tm.numTraces())
#       8 attack.setTraceStart(0)
#       9 attack.setTracesPerAttack()
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\common\utils\parameter.py in func_wrapper(*args, **kargs)
#     749                 if parameter != "":
#     750                     tmp = args[0].findParam(parameter)
# --> 751                     tmp.setValue(args[1], blockSignal=tmp.opts["set"], **kargs)
#     752             # todo - use inspect to remove things from kargs that are handled by setvalue above
#     753             if "addToList" in kargs:
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\common\utils\parameter.py in setValue(self, value, blockSignal, blockAction, init, ignoreReadonly, echo, addToList)
#     356                 self.sigValueChanged.emit(value)
#     357             else:
# --> 358                 self.sigValueChanged.emit(value, blockSignal=self.setValue)
#     359         finally:
#     360             if blockSignal is not None:
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\common\utils\util.py in emit(self, *args, **kwargs)
#     231                     targetObj = target()
#     232                     if targetObj is not None:
# --> 233                         method(targetObj, *args, **kwargs)
#     234
#     235
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\common\utils\parameter.py in func_wrapper(*args, **kargs)
#     753             if "addToList" in kargs:
#     754                 del kargs["addToList"]
# --> 755             func(*args, **kargs)
#     756
#     757         return func_wrapper
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\common\utils\tracesource.py in setTraceSource(self, traceSource)
#     125             self._traceSource.sigTracesChanged.disconnect(self.tracesUpdated)
#     126         if traceSource:
# --> 127             traceSource.sigTracesChanged.connect(self.tracesUpdated)
#     128         self._traceSource = traceSource
#     129         self.tracesUpdated()
#
# AttributeError: 'int' object has no attribute 'sigTracesChanged'
# Test failed in cell 21: ValueError: max() arg is an empty sequence
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e0ebbcde978a> in <module>
#       1 cb = cw.getJupyterCallback(attack)
# ----> 2 attack_results = attack.processTracesNoGUI(cb)
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\analyzer\attacks\_base.py in processTracesNoGUI(self, callback, show_progress_bar)
#     158     # for backwards compatability
#     159     def processTracesNoGUI(self, callback=None, show_progress_bar=False):
# --> 160         return self.processTraces(callback, show_progress_bar)
#     161
#     162     def setProject(self, project):
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\analyzer\attacks\_base.py in processTraces(self, callback, show_progress_bar)
#     152
#     153                 # TODO:support start/end point different per byte
# --> 154                 self.attack.addTraces(self.getTraceSource(), (startingTrace, endingTrace), progressBar, pointRange=self.getPointRange(None))
#     155
#     156         return self.attack.getStatistics()
#
# c:\users\user\code\term2\chipwhisperer\software\chipwhisperer\analyzer\attacks\cpa_algorithms\progressive.py in addTraces(self, traceSource, tracerange, progressBar, pointRange)
#     172
#     173         pbcnt = 0
# --> 174         cpa = [None]*(max(self.brange)+1)
#     175         for bnum in self.brange:
#     176             cpa[bnum] = CPAProgressiveOneSubkey(self.model)
#
# ValueError: max() arg is an empty sequence
# Test failed in cell 25: NameError: name 'attack_results' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-108be3eccb9c> in <module>
#       1 from bokeh.plotting import figure, show
#       2 from bokeh.io import output_notebook
# ----> 3 plot_data = cw.analyzerPlots(attack_results)
#       4
#       5 output_notebook()
#
# NameError: name 'attack_results' is not defined
# Test failed in cell 28: NameError: name 'attack_results' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-625ed4d05490> in <module>
#       1 key = np.array(project.traceManager().getKnownKey(0))
# ----> 2 recv_key = [kguess[0][0] for kguess in attack_results.findMaximums()]
#       3 assert np.all((key == recv_key)), "Failed to recover encryption key\nGot: {}\nExpected: {}".format(recv_key, key)
#
# NameError: name 'attack_results' is not defined
# Test failed in cell 29: NameError: name 'attack_results' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3c9243656bdd> in <module>
# ----> 1 assert (attack_results.pge == [0]*16), "PGE for some bytes not zero: {}".format(attack_results.pge)
#
# NameError: name 'attack_results' is not defined

# %%
test_notebook('PA_Multi_1-Breaking_AES-256_Bootloader.ipynb')

# %%
test_notebook('Fault_1-Introduction_to_Clock_Glitch_Attacks.ipynb')
test_notebook('Fault_3-Glitch_Buffer_Attacks.ipynb')
